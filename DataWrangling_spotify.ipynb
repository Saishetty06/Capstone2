# %%
#  Importing the pandas, numpy, matplotlib, seaborn libraries as pd, np, plt and sns respectivelyy. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# from library.sb_utils import save_file

# %%
pwd
# Out:
# 'H:\\DataCamp\\Capstone2'

# %%
# loading the spotify data file 
# spotify_data = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data.csv')
spotify_data = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data.csv')
spotify_data_genre = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data_by_genres.csv')
spotify_data_artist = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data_by_artist.csv')
spotify_data_w_genre = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data_w_genres.csv')
spotify_data_year = pd.read_csv('H:/DataCamp/Capstone2/Spotify_datases/data_by_year.csv')
# print(spotify_data.head())

# %%
spotify_data.columns, spotify_data_genre.columns, spotify_data_artist.columns, spotify_data_w_genre.columns , spotify_data_year.columns
# Out:
# (Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#         'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#         'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#         'valence', 'year'],
#        dtype='object'),
#  Index(['genres', 'acousticness', 'danceability', 'duration_ms', 'energy',
#         'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#         'valence', 'popularity', 'key', 'mode'],
#        dtype='object'),
#  Index(['artists', 'acousticness', 'danceability', 'duration_ms', 'energy',
#         'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#         'valence', 'popularity', 'key', 'mode', 'count'],
#        dtype='object'),
#  Index(['artists', 'acousticness', 'danceability', 'duration_ms', 'energy',
#         'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#         'valence', 'popularity', 'key', 'mode', 'count', 'genres'],
# ...

# %%
# Looking for shape of each dataset
spotify_data.shape, spotify_data_genre.shape, spotify_data_artist.shape,  spotify_data_w_genre.shape , spotify_data_year.shape
# Out:
# ((174389, 19), (3232, 14), (32539, 15), (32539, 16), (102, 14))

# %%
# see a information of the data
spotify_data.info()
spotify_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  datetime64[ns]
# ...

# %%
# seeing the type of columns in the data file
# spotify_data.dtypes

# %%
# Converting release_date to date_time
spotify_data["release_date"]= pd.to_datetime(spotify_data["release_date"])
spotify_data.dtypes
# Out:
# acousticness               float64
# artists                     object
# danceability               float64
# duration_ms                  int64
# energy                     float64
# explicit                     int64
# id                          object
# instrumentalness           float64
# key                          int64
# liveness                   float64
# loudness                   float64
# mode                         int64
# name                        object
# popularity                   int64
# release_date        datetime64[ns]
# speechiness                float64
# tempo                      float64
# valence                    float64
# year                         int64
# dtype: object

# %%
# Removing brackets and single and double inverted commas from artists column
spotify_data['artists']= spotify_data['artists'].str.replace('"', '')
spotify_data['artists']= spotify_data['artists'].str.replace("'", '')
spotify_data['artists'] = spotify_data['artists'].str.strip('[]').astype(object)

spotify_data.head()
# spotify_data.dtypes
# Out:
#    acousticness               artists  danceability  duration_ms  energy  \
# 0      0.991000           Mamie Smith         0.598       168333   0.224
# 1      0.643000  Screamin Jay Hawkins         0.852       150200   0.517
# 2      0.993000           Mamie Smith         0.647       163827   0.186
# 3      0.000173       Oscar Velazquez         0.730       422087   0.798
# 4      0.295000                  Mixe         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
# Checking for null values
spotify_data.isna().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
# plt.matshow(spotify_data.corr())
# plt.show()
corr1=spotify_data.corr()
corr1.style.background_gradient(cmap='coolwarm',axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_60cfd_row0_col0,#T_60cfd_row1_col1,#T_60cfd_row2_col2,#T_60cfd_row3_col3,#T_60cfd_row4_col4,#T_60cfd_row5_col5,#T_60cfd_row6_col6,#T_60cfd_row7_col7,#T_60cfd_row8_col8,#T_60cfd_row9_col9,#T_60cfd_row10_col10,#T_60cfd_row11_col11,#T_60cfd_row12_col12,#T_60cfd_row13_col13,#T_60cfd_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_60cfd_row0_col1,#T_60cfd_row1_col0{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_60cfd_row0_col2,#T_60cfd_row2_col0{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_60cfd_row0_col3,#T_60cfd_row3_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_60cfd_row0_col4,#T_60cfd_row4_col0{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_60cfd_row0_col5,#T_60cfd_row5_col0{
#             background-color:  #ead4c8;
# ...

# %%
corr = spotify_data.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Overview-
#  In this part, I loaded the data into jupyter notebook and converted the 'release_year' column into datetime and removed the
#  "[]" from the 'artists' column. I looked for any missing values and found that the dataset doesn't have any missing values. I performed the correlation between the 19 features that the dataset contains and found that 'energy-loudness','danceability-valence' had higher correlation values, which can tell us that, these parameters will be most likely be useful in determining/predicting the next song/artist track (when the data is trained using supervised or unsupervised learning).
